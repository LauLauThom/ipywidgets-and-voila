# %% [markdown]
# # Interactive plots with matplotlib / ipywidgets / voila
#
# Demonstrate interactive plots with ipywidgets and matplotlib.
# This notebook is largely derived from https://kapernikov.com/ipywidgets-with-matplotlib/

# %%
# %matplotlib widget
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np

# %%
# set up plot
fig, ax = plt.subplots()
ax.set_ylim([-4, 4])
ax.grid(True)
 
# generate x values
x = np.linspace(0, 2 * np.pi, 100) # 100 datapoints, regularly spaced on [0; 2.Pi]


def sinewave(x, w, amp, phi):
    """
    Return a sine for x with angular frequeny w and amplitude amp.
    """
    return amp * np.sin(w * (x-phi))
 
 
@widgets.interact(w = (0, 10, 1), amp=(0, 4, .1), phi=(0, 2*np.pi+0.01, 0.01)) # defined for each paramter (start, stop, step) for the widget, here sliders by default for numerical data
def update_plot(w = 1.0, amp=1, phi=0):
    """
    Update the plot/replot, happens each time a slider value is changed.   
    remove old lines from plot and plot new one.  
    """
    print("Amplitude is now :", amp) # Just print some feedback, to illustrate that you can also have interactive info displayed.
    [line.remove() for line in ax.lines]
    ax.plot(x, sinewave(x, w, amp, phi), color='C0')

# UNCOMMENT THIS to show dropdown functionality
#@widgets.interact(fruit = ["banana", "apple", "cherry"])
#def print_fruit(fruit = "banana"):
#    print("Selected :", fruit)
# Out:
# interactive(children=(IntSlider(value=1, description='w', max=10), FloatSlider(value=1.0, description='amp', m…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
